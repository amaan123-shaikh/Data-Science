# %%
#count vowels in a string
x="hellow world"
print(x.lower().count("a")+x.lower().count("e")+x.lower().count("i")+x.lower().count("o")+x.lower().count("u"))
# Out:
# 3

# %%
Light=input("light:").lower()
if Light=="red":
    print("STOP")
elif Light=="yellow":
    print("LOOK")
elif Light=="green":
    print("GO")
else:
    print("LIGHT IS BROKEN")
# Out:
# GO

# %%
marks=int(input("enter the marks:"))
if marks>=90:
    print("Pass with A grade")
elif marks>=80 and marks <90:
    print("pass with B grade")
elif marks>=70 and marks<80:
    print("Pass with C grade")
else:
    print("Pass with d grade")
# Out:
# Pass with d grade

# %%
food=input("enter the food:")
eat="Yes" if food == "cake" else "No"
print(eat)
#__
foods=input("enter the foor name:")
taste="sweet" if foods=="jalebi" or food=="cake" else ("not sweet")
print(taste)
# Out:
# Yes
# sweet

# %%
age=int(input("enter the age:"))
vote=("yes","no")[age<18]
print(vote)

salary=int(input("enter the saary:"))
tax=salary*(0.1,0.2) [salary<50000]
print(tax)
# Out:
# yes
# 5000.0

# %%
#count vowels
x="Hello world"
count=0
vowels="aeiou"
for char in x:
    if char in vowels:
        count+=1
print(count)
# Out:
# 3

# %%
#reverse string
x="python"
print(x[::-1])
# Out:
# nohtyp

# %%
#palindrome check
x="madam"
print(x==x[::-1])
# Out:
# True

# %%
#remove space
x="hellow world"
print(x.replace(" ",""))
# Out:
# hellowworld

# %%
#count word
x="i love python programming"
print(len(x.split()))
# Out:
# 4

# %%
#character frequency
x="apple"
freq={}
for char in x:
    freq[char]=freq.get(char,0)+1
print(freq)
# Out:
# {'a': 1, 'p': 2, 'l': 1, 'e': 1}

# %%
x="programming"
char="g"
position=[i for i in range(len(x)) if x[i]==char]
print(position)
# Out:
# [3, 10]

# %%
#capitalize word
x="python is fun"
print(x.title())
# Out:
# Python Is Fun

# %%
#replace first occurrence
x="the sky is blue"
print(x.replace("the","a",1))
# Out:
# a sky is blue

# %%
#remove duplicate character
x="programming"
result=""
for char in x:
    if char not in result:
        result+=char
print(result)
# Out:
# progamin

# %%
#uppercase and lowercase
x="Hellow world"
upper=sum(1 for char in x if char.isupper())
lowerr=sum(1 for char in x if char.islower())
print(upper,lowerr)
# Out:
# 1 10

# %%
#swape case
x="hellow"
print(x.swapcase())
# Out:
# HELLOW

# %%
#anagram check
a="listen"
b="silent"
print(sorted(a)==sorted(b))
# Out:
# True

# %%
#remove specific character
x="hellow world"
print(x.replace("l",""))
# Out:
# heow word

# %%
#split into character
x="hellow"
print(list(x))
# Out:
# ['h', 'e', 'l', 'l', 'o', 'w']

# %%
#longest word
x="python is powerful"
print(max(x.split(),key=len))
# Out:
# powerful

# %%
#remove special character
import re
x="hellow@123!"
print(re.sub(r'[^a-zA-Z0-9]','',x))
# Out:
# hellow123

# %%
#replace vowels with *
x = "hellow"
vowels = "aeiou"
output = ""
for char in x:
    if char in vowels:
        output += "*"
    else:
        output += char
print(output)
# Out:
# h*ll*w

# %%
#sort character
x="dcba"
print(''.join(sorted(x)))
# Out:
# abcd

# %%
#second most frequent charcter
from collections import Counter
x="aabbccc"
freq=Counter(x)
print(freq.most_common(2)[1][0])
# Out:
# a

# %%
#valid email
import re
email = "test@example.com"
print(bool(re.match(r'^[\w\.-]+@[\w\.-]+\.\w+$', email)))
# Out:
# True

# %%
#replace multiple spaces
x="python is  fun"
print(" ".join(x.split()))
# Out:
# python is fun

# %%
#convert strng to list (without split)
x="i love python"
x = "i love python"
result = []
for char in x:
    result.append(char)

print(result)
# Out:
# ['i', ' ', 'l', 'o', 'v', 'e', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %%
#even position character
x="python"
print([x[i] for i in range(0,len(x),2)])
# Out:
# ['p', 't', 'o']

# %%
#odd position character
x="python"
print([x[i] for i in range(1,len(x),2)])
# Out:
# ['y', 'h', 'n']

# %%
x="12345"
print(x.isdigit())
# Out:
# True

# %%
#count alphabets digits,specail
x="python@123"
alpha=0
digit=0
special=0
for char in x:
    if char.isalpha():
        alpha+=1
    elif char.isdigit():
        digit+=1
    else:
        special+=1
print(alpha,digit,special)
# Out:
# 6 3 1

# %%
#all substrings
x = "abc"
substrings = []
for i in range(len(x)):
    for j in range(i + 1, len(x) + 1):
        substrings.append(x[i:j])

print(substrings)
# Out:
# ['a', 'ab', 'abc', 'b', 'bc', 'c']

# %%
#first letter uppercase
x="python"
print(x.title())
# Out:
# Python

# %%
#lower case without lower()
s = "HELLO"
print(''.join(chr(ord(ch)+32) for ch in s))
# Out:
# hello

# %%
#start and end with same charater
x="level"
print(x[0]==x[-1])
# Out:
# True

# %%
#next ascii character
s = "abc"
print(''.join(chr(ord(ch)+1) for ch in s))
# Out:
# bcd

# %%
#remove punctuation
import string
x = "Hello, world! How's Python?"
result = ""
for char in x:
    if char not in string.punctuation:
        result += char
print(result)
# Out:
# Hello world Hows Python

# %%
#longest substring without repeat
x="abcabcbb"
print(len(set(x)))
# Out:
# 3

# %%
import re
camel = "CamelCaseExample"
snake = re.sub(r'(?<!^)(?=[A-Z])', '_', camel).lower()
print(snake)
# Out:
# camel_case_example

# %%
#rotation check
a, b = "abcd", "cdab"
print(b in a+a)
# Out:
# True

# %%
#word frequency
from collections import Counter
s = "python is fun python"
print(dict(Counter(s.split())))
# Out:
# {'python': 2, 'is': 1, 'fun': 1}

# %%
#convert sentence into peg latin
s = "python is fun"
print(" ".join(word[1:] + word[0] + "ay" for word in s.split()))
# Out:
# ythonpay siay unfay

# %%
#striing formating
name="amaan"
print(f"hello,{name}")
# Out:
# hello,amaan

# %%
#caesar cipher
s = "abc"
print(''.join(chr(ord(ch)+3) for ch in s))
# Out:
# def

# %%
#alternate merge
a,b="abc","123"
print(''.join(x+y for x,y in zip(a,b)))
# Out:
# a1b2c3

# %%
#first non repeating
from collections import Counter
x="swiss"
for char in x:
    if Counter(x)[char]==1:
        print(char)
        break
# Out:
# w

# %%
#remove prefix
x="unhappy"
print(x.removeprefix("un"))
# Out:
# happy

# %%
#replace substring
x="aaabaa"
print(x.replace("aa","c"))
# Out:
# cabc

# %%
#mask except last 4
s = "1234567890"
print("*"*(len(s)-4) + s[-4:])
# Out:
# ******7890

# %%
#valid identifier
x="var_name"
print(x.isidentifier())
# Out:
# True

# %%
#common characters
x="python","java"
print(list(set("pythan") & set("java")))
# Out:
# ['a']

# %%
#word frequency
x="python python code"
print(dict(Counter(x.split())))
# Out:
# {'python': 2, 'code': 1}

# %%
#remoe html tag
import re
s = "<p>Hello</p>"
print(re.sub(r'<.*?>', '', s))
# Out:
# Hello

# %%
#count consonants
x="hellow world"
print(sum(1 for char in x.lower() if char.isalpha() and char not in "aeiou"))
# Out:
# 8

# %%
#special character check
x="hellow@world"
print(any(not char.isalnum() for char in x))
# Out:
# True

# %%
#remove digits
x="abc123xyz"
print(''.join(char for char in x if not char.isdigit()))
# Out:
# abcxyz

# %%
#ascii values
x="abc"
print([ord(char) for char in x])
# Out:
# [97, 98, 99]

# %%
#extract number
import re
x = "abc12xyz45"
print(list(map(int, re.findall(r'\d+', s))))
# Out:
# [12, 45]

# %%
#replace consonants
x="hellow"
print(''.join('#' if char.isalpha() and char not in "aeiouAEIOU" else char for char in x))
# Out:
# #e##o#

# %%
#middle character
x = "Python"
mid = len(s)//2
print(x[mid-1:mid+1])
# Out:
# on

# %%
#remove last n chars
x="hellow world"
n=5
print(x[:-n])
# Out:
# hellow

# %%
#substring count
x="ababab"
print(x.count("ab"))
# Out:
# 3

# %%
#remove vowels
x="education"
print(''.join(char for char in x if char.lower() not in "aeiou"))
# Out:
# dctn

# %%
#numeric string
s = "123.45"
print(s.replace('.', '', 1).isdigit())
# Out:
# True

# %%
# replace number to word
x="i have 2 apples"
print(x.replace("2","two"))
# Out:
# i have two apples

# %%
#word with most vowels
x="python is awesome"
print(max(x.split(),key=lambda w:sum(char in "aeiou" for char in w)))
# Out:
# awesome

# %%
#list to sentence
lst=["python","is","fun"]
print(" ".join(lst))
# Out:
# python is fun

# %%
# Remove leading & trailing special chars
s = "***Hello***"
print(s.strip("*"))
# Out:
# Hello

# %%
# Replace every second char
s = "abcdef"
print(''.join(ch if i%2==0 else '*' for i,ch in enumerate(s)))
# Out:
# a*c*e*

# %%
# Extract alphabets
s = "abc123!@#"
print(''.join(ch for ch in s if ch.isalpha()))
# Out:
# abc

# %%
# Words starting with letter
s = "Python is perfect for programming"
print([w for w in s.split() if w.lower().startswith('p')])
# Out:
# ['Python', 'perfect', 'programming']

# %%
# Replace spaces with hyphens
s = "Python is awesome"
print(s.replace(" ", "-"))
# Out:
# Python-is-awesome
